# %%
import numpy as np
import xarray as xr
import pandas as pd
import cartopy.crs as ccrs
import cartopy
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import datetime
import os


plt.rcParams['figure.figsize'] = (10, 4)

# %%
data_dir = '/Users/pvb/Dropbox/Oceanografia/Data/Satelite/noaa.oisst.v2.highres/NC'

# %%
year = datetime.date.today().year
fileThisYear = 'sst.day.mean.'+str(year)+'.nc'

# %%
data = xr.open_dataset(data_dir+'/'+fileThisYear)
sst = data.sst

# %%
sst.time[-1]
# Out:
# <xarray.DataArray 'time' ()>
# array('2023-05-04T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2023-05-04
# Attributes:
#     long_name:     Time
#     delta_t:       0000-00-01 00:00:00
#     avg_period:    0000-00-01 00:00:00
#     axis:          T
#     actual_range:  [81449. 81572.]

# %%
fig = plt.figure(figsize=(14,8))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
ax.gridlines(draw_labels=True, xlocs=np.arange(-180,180,30))
sst.mean(dim='time').plot(ax=ax, transform=ccrs.PlateCarree(),
         vmin=2, vmax=30, cbar_kwargs={'shrink': 0.8},cmap = "jet");
# Out:
# /Users/pvb/miniconda3/envs/Ocean/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/pvb/miniconda3/envs/Ocean/lib/python3.11/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /Users/pvb/miniconda3/envs/Ocean/lib/python3.11/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(

# %%
l=sst.mean(dim='time').to_numpy()

# %%
l.shape
# Out:
# (720, 1440)
