# %%
import matplotlib.pyplot as plt  # plotting library
import numpy as np  # numerical library
import xarray as xr  # netCDF library
import cartopy  # Map projections libary
import cartopy.crs as ccrs  # Projections list
import cftime
# Some defaults:
plt.rcParams['figure.figsize'] = (12, 5)  # Default plot size

# %%
file1='/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_Temperature_2019.nc'
dataTemp = xr.open_mfdataset(file1, decode_times=False)
dataTemp
# Out:
# <xarray.Dataset>
# Dimensions:                   (LONGITUDE: 360, LATITUDE: 145, PRESSURE: 58,
#                                TIME: 180)
# Coordinates:
#   * LONGITUDE                 (LONGITUDE) float32 20.5 21.5 22.5 ... 378.5 379.5
#   * LATITUDE                  (LATITUDE) float32 -64.5 -63.5 -62.5 ... 78.5 79.5
#   * PRESSURE                  (PRESSURE) float32 2.5 10.0 ... 1.9e+03 1.975e+03
#   * TIME                      (TIME) float32 0.5 1.5 2.5 ... 177.5 178.5 179.5
# Data variables:
#     ARGO_TEMPERATURE_MEAN     (PRESSURE, LATITUDE, LONGITUDE) float32 dask.array<chunksize=(58, 145, 360), meta=np.ndarray>
#     ARGO_TEMPERATURE_ANOMALY  (TIME, PRESSURE, LATITUDE, LONGITUDE) float32 dask.array<chunksize=(180, 58, 145, 360), meta=np.ndarray>
#     BATHYMETRY_MASK           (PRESSURE, LATITUDE, LONGITUDE) float32 dask.array<chunksize=(58, 145, 360), meta=np.ndarray>
# ...

# %%
def fix_calendar(ds, timevar='TIME'):
  if ds[timevar].attrs['calendar'] == '360':
    ds[timevar].attrs['calendar'] = '360_day'
    return ds

dataTemp = fix_calendar(dataTemp)
dataTemp = xr.decode_cf(dataTemp)
dataTemp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 6
#       3     ds[timevar].attrs['calendar'] = '360_day'
#       4     return ds
# ----> 6 dataTemp = fix_calendar(dataTemp)
#       7 dataTemp = xr.decode_cf(dataTemp)
#       8 dataTemp
#
# Cell In[65], line 2, in fix_calendar(ds, timevar)
#       1 def fix_calendar(ds, timevar='TIME'):
# ----> 2   if ds[timevar].attrs['calendar'] == '360':
#       3     ds[timevar].attrs['calendar'] = '360_day'
#       4     return ds
#
# KeyError: 'calendar'

# %%
files = ['/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_201901_2019.nc',
         '/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_201902_2019.nc']

# %%
files
# Out:
# ['/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_Salinity_2019.nc',
#  '/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_201901_2019.nc',
#  '/Users/pvb/Dropbox/Oceanografia/Data/Argo/Gridded/RG_ArgoClim/NC/RG_ArgoClim_201902_2019.nc']

# %%
data = xr.open_mfdataset(files, decode_times=False)
# Out:
# /Users/pvb/miniconda3/envs/Ocean/lib/python3.11/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/pvb/miniconda3/envs/Ocean/lib/python3.11/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
# ...

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:                   (LONGITUDE: 360, LATITUDE: 145, PRESSURE: 58,
#                                TIME: 2)
# Coordinates:
#   * LONGITUDE                 (LONGITUDE) float32 20.5 21.5 22.5 ... 378.5 379.5
#   * LATITUDE                  (LATITUDE) float32 -64.5 -63.5 -62.5 ... 78.5 79.5
#   * PRESSURE                  (PRESSURE) float32 2.5 10.0 ... 1.9e+03 1.975e+03
#   * TIME                      (TIME) float32 180.5 181.5
# Data variables:
#     ARGO_TEMPERATURE_ANOMALY  (TIME, PRESSURE, LATITUDE, LONGITUDE) float32 dask.array<chunksize=(1, 58, 145, 360), meta=np.ndarray>
#     ARGO_SALINITY_ANOMALY     (TIME, PRESSURE, LATITUDE, LONGITUDE) float32 dask.array<chunksize=(1, 58, 145, 360), meta=np.ndarray>
