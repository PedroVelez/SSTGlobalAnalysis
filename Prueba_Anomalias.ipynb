# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from matplotlib.dates import DateFormatter
import datetime
import os


plt.rcParams['figure.figsize'] = (10, 4)

# %%
# Daily data

data = xr.open_dataset('./data/sstd_anom_mean_GO.nc')
sstdGO_anom = data.sst

data = xr.open_dataset('./data/sstd_anom_mean_NH.nc')
sstdNH_anom = data.sst

data = xr.open_dataset('./data/sstd_anom_mean_SH.nc')
sstdSH_anom = data.sst
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/envs/ocean/lib/python3.11/site-packages/xarray/backends/file_manager.py:210, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     209 try:
# --> 210     file = self._cache[self._key]
#     211 except KeyError:
#
# File /opt/conda/envs/ocean/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/pvb/Analisis/SSTGlobalAnalysis/data/sstd_anom_mean_NH.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '75a44ad2-4e0f-484f-b01c-d065a5b077a9']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
sstdSH_anom_rolling = sstdSH_anom.rolling(time = 360 , center = True).mean()
sstdNH_anom_rolling = sstdNH_anom.rolling(time = 360 , center = True).mean()
sstdGO_anom_rolling = sstdGO_anom.rolling(time = 360 , center = True).mean()

# %%
fig,ax = plt.subplots()
#ax.plot(sstdGO_anom.time,sstdGO_anom,'b')
#ax.plot(sstdNH_anom.time,sstdNH_anom,'r')
#ax.plot(sstdSH_anom.time,sstdSH_anom,'c')


ax.plot(sstdGO_anom_rolling.time,sstdGO_anom_rolling,'b',label='Oceano global')
ax.plot(sstdNH_anom_rolling.time,sstdNH_anom_rolling,'r',label='Hemisferio norte')
ax.plot(sstdSH_anom_rolling.time,sstdSH_anom_rolling,'c',label='Hemisferio sur')
ax.grid()
